// %%
%status
// Out:
// clang-repl found: clang-repl LLVM (http://llvm.org/):
//   LLVM version 19.1.6
//   Optimized build.
//
// -- repl in ---------------------------
// #include <vector>
// -- repl out begin --------------------
// #include <vector>
//
// -- repl out end ----------------------
// alive:     True
// timed_out: False
// error:     False
// --------------------------------------
//
// -- repl in ---------------------------
// #include <iostream>
// -- repl out begin --------------------
// #include <iostream>
//
// -- repl out end ----------------------
// alive:     True
// timed_out: False
// error:     False
// --------------------------------------
//
// -- repl in ---------------------------
// %lib libomp.so
// -- repl out begin --------------------
// %lib libomp.so
//
// -- repl out end ----------------------
// alive:     True
// timed_out: False
// error:     False
// --------------------------------------

// %%
%main
std::cout << "hellO!" << std::endl;
// Out:
// hellO!

// %%
%main
int a;
std::cin >>  a; // not supported this will timeout
// Out:
// could not execute cell: clang-repl session is dead; you need to restart the kernel.
